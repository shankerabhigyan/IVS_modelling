# %%
import json

# %%
path = './data/data_raw/spy_options_data_21.json'

# %%
data = None
with open(path, 'r') as f:
    data = json.load(f)

# %%
data[0][0]['date']
# Out:
# '2021-01-04'

# %%
dates = set()
for d in data:
    for obj in d:
        if obj:
            dates.add(obj['date'])

# %%
dates = sorted(list(dates))
print(dates)
print(len(dates))
# Out:
# ['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22', '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28', '2021-01-29', '2021-02-01', '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05', '2021-02-08', '2021-02-09', '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-16', '2021-02-17', '2021-02-18', '2021-02-19', '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25', '2021-02-26', '2021-03-01', '2021-03-02', '2021-03-03', '2021-03-04', '2021-03-05', '2021-03-08', '2021-03-09', '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-15', '2021-03-16', '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-22', '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26', '2021-03-29', '2021-03-30', '2021-03-31', '2021-04-01', '2021-04-05', '2021-04-06', '2021-04-07', '2021-04-08', '2021-04-09', '2021-04-12', '2021-04-13', '2021-04-14', '2021-04-15', '20
# ...

# %%
data_ = []
for d in data:
    if d[0]['date'] == '2021-10-14':
        data_ = d
        break

# %%
data_
# Out:
# [{'contractID': 'SPY211015C00190000',
#   'symbol': 'SPY',
#   'expiration': '2021-10-15',
#   'strike': '190.00',
#   'type': 'call',
#   'last': '243.93',
#   'mark': '252.50',
#   'bid': '252.20',
#   'bid_size': '10',
#   'ask': '252.80',
#   'ask_size': '10',
#   'volume': '0',
#   'open_interest': '0',
#   'date': '2021-10-14',
#   'implied_volatility': '4.57924',
#   'delta': '1.00000',
#   'gamma': '0.00000',
#   'theta': '-0.00152',
#   'vega': '0.00000',
#   'rho': '0.00521'},
#  {'contractID': 'SPY211015P00190000',
#   'symbol': 'SPY',
#   'expiration': '2021-10-15',
#   'strike': '190.00',
#   'type': 'put',
#   'last': '0.00',
#   'mark': '0.01',
#   'bid': '0.00',
#   'bid_size': '0',
#   'ask': '0.01',
#   'ask_size': '7331',
#   'volume': '0',
#   'open_interest': '9745',
#   'date': '2021-10-14',
#   'implied_volatility': '4.91758',
#   'delta': '-0.00032',
#   'gamma': '0.00001',
#   'theta': '-0.24489',
#   'vega': '0.00027',
#   'rho': '-0.00000'},
# ...
