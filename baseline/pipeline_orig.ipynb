# %% [markdown]
# # Full Two Step Pipeline

# %%
# imports
import pandas as pd
import numpy as np
import wandb

# %% [markdown]
# ## Creating Surface

# %%
from data_handler import preprocessData, fitSurface

# %%
json_path = "../data/raw/yearwise/spy_options_data_20.json" #../data/raw/yearwise/spy_options_data_22.json
csv_save_path = "../data/processed/pca/predicted_iv20.csv" # ../data/processed/predicted_iv22.csv
preprocess = preprocessData(json_path)
df = preprocess.fit()
print(df.head())
fit = fitSurface(df)
predicted_iv = fit.fit()
print(predicted_iv)
predicted_iv.to_csv(csv_save_path, index=False)
# Out:
#          date           m         tau    delta       IV
# 0  2020-01-02  -2.5906870   1.9589041  0.00013  0.56982
# 1  2020-01-02  -2.5796121   1.0383562  0.00013  0.77820
# 2  2020-01-02  -2.5786092  0.96164384  0.00013  0.80823
# 4  2020-01-02  -2.4107383   1.9589041  0.00014  0.52866
# 5  2020-01-02  -2.3992833   1.0383562  0.00014  0.72164
#           date       tau         m        IV
# 0   2020-01-02  0.027397 -0.510826  0.286845
# 0   2020-01-02  0.027397 -0.223144  0.235749
# 0   2020-01-02  0.027397 -0.105361  0.224306
# 0   2020-01-02  0.027397 -0.051293  0.220896
# 0   2020-01-02  0.027397 -0.025318  0.219671
# ..         ...       ...       ...       ...
# 0   2020-12-31  2.000000  0.182322  0.170821
# 0   2020-12-31  2.000000  0.262364  0.180869
# 0   2020-12-31  2.000000  0.405465  0.208168
# 0   2020-12-31  2.000000  0.559616  0.250973
# 0   2020-12-31  2.000000  0.693147  0.299285
#
# [38808 rows x 4 columns]

# %% [markdown]
# ## PCA Feature Extraction

# %%
from feature_extraction import featureExtractor

# %%
paths = [
    "../data/processed/pca/predicted_iv16.csv",
    "../data/processed/pca/predicted_iv17.csv",
    "../data/processed/pca/predicted_iv18.csv",
    "../data/processed/pca/predicted_iv19.csv",
    "../data/processed/pca/predicted_iv20.csv"
]
save_path = "../data/processed/features_pca_iv16-20.csv"

fe = featureExtractor(paths, save_path)
fe.transform()
fe.fit()
# Out:
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# ...
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# Features saved to ../data/processed/features_pca_iv16-20.csv
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/feature_extraction.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   features[date] = feature
#             date  feature1  feature2  feature3
# 0     2016-01-05 -2.946036  0.399305  2.333101
# 1     2016-01-06 -2.890993  0.153763  2.388737
# 2     2016-01-07 -4.476846  2.506460  2.701483
# 3     2016-01-08 -3.925725  1.810529  2.540009
# 4     2016-01-11 -4.277851  2.453446  2.562114
# ...          ...       ...       ...       ...
# 1250  2020-12-24 -4.587537  2.128875  3.008283
# 1251  2020-12-28 -3.938034  1.187221  2.865200
# 1252  2020-12-29 -3.785889  0.876443  2.871706
# 1253  2020-12-30 -4.927338  2.579399  3.099356
# 1254  2020-12-31 -3.933485  1.446131  2.747809
#
# [1255 rows x 4 columns]

# %%
# sanity check to see if there are no repeated values or NaNs
df = pd.read_csv(save_path)
print(df.head())
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.shape)
print(df.tail())
# Out:
#          date  feature1  feature2  feature3
# 0  2016-01-05 -2.946036  0.399305  2.333101
# 1  2016-01-06 -2.890993  0.153763  2.388737
# 2  2016-01-07 -4.476846  2.506460  2.701483
# 3  2016-01-08 -3.925725  1.810529  2.540009
# 4  2016-01-11 -4.277851  2.453446  2.562114
# date        0
# feature1    0
# feature2    0
# feature3    0
# dtype: int64
# 0
# (1255, 4)
#             date  feature1  feature2  feature3
# 1250  2020-12-24 -4.587537  2.128875  3.008283
# 1251  2020-12-28 -3.938034  1.187221  2.865200
# 1252  2020-12-29 -3.785889  0.876443  2.871706
# 1253  2020-12-30 -4.927338  2.579399  3.099356
# 1254  2020-12-31 -3.933485  1.446131  2.747809

# %% [markdown]
# ## VAE Feature Extraction

# %%
from models.vae_master import VAE, IVSDataset, IVSFeatureExtractor

# %%
# bring here

# %% [markdown]
# ## LSTM

# %%
from models.lstm import CustomLSTMCell, CustomLSTMModel, ModelManager, DatasetManager

# %%
# pca_path = "../data/processed/features_pca_iv16-20.csv"
# dataset = DatasetManager(pca_path)
# features, targets = dataset.make_train_target_pairs()
# print('Features shape:', features.shape)
# print('Targets shape:', targets.shape)

# %%
# #Split the dataset into training and validation sets
# split = int(0.8 * len(features))
# train_features, val_features = features[:split], features[split:]
# train_targets, val_targets = targets[:split], targets[split:]

# no split
# train_features, train_targets = features, targets

# %%
# print('Initializing model...')
# model_path = './lstm1620_256.pth'
# model = ModelManager(input_dim=9, hidden_dim=256, output_dim=3, model_path=model_path, learning_rate=0.01)
# model.train(train_features, train_targets, epochs=160000)

# #val_loader = DataLoader(TensorDataset(val_features, val_targets), batch_size=1, shuffle=False)
# #model.validate(val_loader)

# model.save_model()

# %% [markdown]
# ## DNN

# %%
import pandas as pd
import numpy as np
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from models.lstm import CustomLSTMCell, CustomLSTMModel, ModelManager, DatasetManager

# %%
lstm_model_path = "./lstm1620_256.pth"
lstm_model = CustomLSTMModel(input_dim=9, hidden_dim=256, output_dim=3)
lstm_model.load_model(model_path=lstm_model_path)
# Out:
# Model loaded from ./lstm1620_256.pth
# /home/shankerabhigyan/code/thesis/thesis-IVS/baseline/models/lstm.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path))

# %%
features = pd.read_csv("../data/processed/features_pca_iv16-20.csv")
features.head()
# Out:
#          date  feature1  feature2  feature3
# 0  2016-01-05 -2.946036  0.399305  2.333101
# 1  2016-01-06 -2.890993  0.153763  2.388737
# 2  2016-01-07 -4.476846  2.506460  2.701483
# 3  2016-01-08 -3.925725  1.810529  2.540009
# 4  2016-01-11 -4.277851  2.453446  2.562114

# %%
for i in range(22,len(features)):
    ma1 = torch.tensor(features.iloc[i-1][['feature1', 'feature2', 'feature3']].astype(float).values, dtype=torch.float32)
    ma5 = torch.tensor(features.iloc[i-5:i][['feature1', 'feature2', 'feature3']].mean(axis=0).values, dtype=torch.float32)
    ma22 = torch.tensor(features.iloc[i-22:i][['feature1', 'feature2', 'feature3']].mean(axis=0).values, dtype=torch.float32)
    feature = torch.cat((ma1, ma5, ma22), dim=0).to(device)
    out = lstm_model.predict(feature)
    for obj in out:
        features.at[i, "F1"] = obj[0].item()
        features.at[i, "F2"] = obj[1].item()
        features.at[i, "F3"] = obj[2].item()

# %%
features = features.dropna().reset_index(drop=True)
features.head()
# Out:
#          date  feature1  feature2  feature3        F1        F2        F3
# 0  2016-02-05 -2.785850  0.208685  2.273442 -3.274983  0.211036  2.728152
# 1  2016-02-08 -2.426245 -0.018148  2.072642 -2.584140 -0.038944  2.221148
# 2  2016-02-09 -2.978782  0.438694  2.333295 -3.021670  0.546963  2.329862
# 3  2016-02-10 -3.273419  0.806418  2.418158 -3.305915  0.986623  2.392399
# 4  2016-02-11 -2.607269  0.123359  2.159899 -2.727583  0.369955  2.155907

# %%
df_iv_path_list = [
    "../data/processed/pca/predicted_iv16.csv",
    "../data/processed/pca/predicted_iv17.csv",
    "../data/processed/pca/predicted_iv18.csv",
    "../data/processed/pca/predicted_iv19.csv",
    "../data/processed/pca/predicted_iv20.csv"
]

# %%
merged_df = pd.DataFrame()
for path in df_iv_path_list:
    df = pd.read_csv(path)
    merged_df = pd.concat([merged_df, df], axis=0)

merged_df = merged_df.reset_index(drop=True)
print(len(merged_df))
merged_df.head()
# Out:
# 193424
#          date       tau         m        IV
# 0  2016-01-04  0.027397 -0.510826  0.326153
# 1  2016-01-04  0.027397 -0.223144  0.291228
# 2  2016-01-04  0.027397 -0.105361  0.286565
# 3  2016-01-04  0.027397 -0.051293  0.286299
# 4  2016-01-04  0.027397 -0.025318  0.286591

# %%
# join the two dataframes using the date column so that we have the corresponding F1, F2, F3 values for each date
df = pd.merge(merged_df, features, on='date')
df.head()
# Out:
#          date       tau         m        IV  feature1  feature2  feature3  \
# 0  2016-02-05  0.027397 -0.510826  0.346719  -2.78585  0.208685  2.273442
# 1  2016-02-05  0.027397 -0.223144  0.309534  -2.78585  0.208685  2.273442
# 2  2016-02-05  0.027397 -0.105361  0.304773  -2.78585  0.208685  2.273442
# 3  2016-02-05  0.027397 -0.051293  0.304623  -2.78585  0.208685  2.273442
# 4  2016-02-05  0.027397 -0.025318  0.305006  -2.78585  0.208685  2.273442
#
#          F1        F2        F3
# 0 -3.274983  0.211036  2.728152
# 1 -3.274983  0.211036  2.728152
# 2 -3.274983  0.211036  2.728152
# 3 -3.274983  0.211036  2.728152
# 4 -3.274983  0.211036  2.728152

# %%
feature_cols = ['F1', 'F2', 'F3']
from models.dnn import IVDataset, IVSDNN, train_model, large_moneyness_penalty, butterfly_arbitrage_penalty, calendar_spread_penalty, safe_divide

# %%
dataset = IVDataset(df, feature_cols)
# Out:
# Tensor shapes:
# Features: torch.Size([189882, 3])
# m: torch.Size([189882, 1])
# tau: torch.Size([189882, 1])
# iv: torch.Size([189882, 1])
#
# Checking for NaN values:
# Features NaN: False
# m NaN: False
# tau NaN: False
# iv NaN: False

# %%
print(dataset.get_input_size())
# Out:
# 5

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(dataset, batch_size=512, shuffle=True)
dnn = IVSDNN(input_size=dataset.get_input_size(), hidden_size=256)

# %%
lambda_penalty=1
num_epochs=500

# %%
import wandb
wandb.init(project="ivs-dnn")
train_model(dnn, train_loader, 100, 0.001, 1, wandb)
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: abhigyanshanker (abx-group). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/home/shankerabhigyan/code/thesis/thesis-IVS/baseline/wandb/run-20241110_222330-qmudmuhp</code>
# Syncing run <strong><a href='https://wandb.ai/abx-group/ivs-dnn/runs/qmudmuhp' target="_blank">denim-leaf-12</a></strong> to <a href='https://wandb.ai/abx-group/ivs-dnn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/abx-group/ivs-dnn' target="_blank">https://wandb.ai/abx-group/ivs-dnn</a>
#  View run at <a href='https://wandb.ai/abx-group/ivs-dnn/runs/qmudmuhp' target="_blank">https://wandb.ai/abx-group/ivs-dnn/runs/qmudmuhp</a>
# /home/shankerabhigyan/miniconda3/envs/torch/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1 || Loss = 27.525697 || Penalty = 27.431397 || Calendar Penalty = 34.483868 || Butterfly Penalty = 30.109589 || Large Moneyness Penalty = 72.563525
# Epoch 2 || Loss = 0.057935 || Penalty = 0.000644 || Calendar Penalty = 0.001517 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000093
# Epoch 3 || Loss = 0.057603 || Penalty = 0.000311 || Calendar Penalty = 0.000505 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000013
# Epoch 4 || Loss = 0.057486 || Penalty = 0.000194 || Calendar Penalty = 0.000239 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000004
# Epoch 5 || Loss = 0.057426 || Penalty = 0.000134 || Calendar Penalty = 0.000133 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000001
# Epoch 6 || Loss = 0.057380 || Penalty = 0.000087 || Calendar Penalty = 0.000086 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000001
# Epoch 7 || Loss = 0.057358 || Penalty = 0.000064 || Calendar Penalty = 0.000063 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 8 || Loss = 0.057343 || Penalty = 0.000050 || Calendar Penalty = 0.000050 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 9 || Loss = 0.057337 || Penalty = 0.000043 || Calendar Penalty = 0.000043 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 10 || Loss = 0.057330 || Penalty = 0.000038 || Calendar Penalty = 0.000038 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 11 || Loss = 0.057327 || Penalty = 0.000035 || Calendar Penalty = 0.000035 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 12 || Loss = 0.057326 || Penalty = 0.000033 || Calendar Penalty = 0.000033 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 13 || Loss = 0.057325 || Penalty = 0.000032 || Calendar Penalty = 0.000032 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 14 || Loss = 0.057325 || Penalty = 0.000032 || Calendar Penalty = 0.000032 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 15 || Loss = 0.057325 || Penalty = 0.000032 || Calendar Penalty = 0.000031 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 16 || Loss = 0.057323 || Penalty = 0.000032 || Calendar Penalty = 0.000031 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 17 || Loss = 0.057324 || Penalty = 0.000031 || Calendar Penalty = 0.000031 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 18 || Loss = 0.057324 || Penalty = 0.000031 || Calendar Penalty = 0.000031 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 19 || Loss = 0.057322 || Penalty = 0.000031 || Calendar Penalty = 0.000030 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 20 || Loss = 0.057321 || Penalty = 0.000030 || Calendar Penalty = 0.000030 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 21 || Loss = 0.057322 || Penalty = 0.000030 || Calendar Penalty = 0.000030 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 22 || Loss = 0.057322 || Penalty = 0.000030 || Calendar Penalty = 0.000030 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 23 || Loss = 0.057322 || Penalty = 0.000029 || Calendar Penalty = 0.000029 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 24 || Loss = 0.057320 || Penalty = 0.000029 || Calendar Penalty = 0.000029 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 25 || Loss = 0.057322 || Penalty = 0.000028 || Calendar Penalty = 0.000028 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 26 || Loss = 0.057320 || Penalty = 0.000028 || Calendar Penalty = 0.000028 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 27 || Loss = 0.057320 || Penalty = 0.000028 || Calendar Penalty = 0.000027 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 28 || Loss = 0.057318 || Penalty = 0.000027 || Calendar Penalty = 0.000027 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 29 || Loss = 0.057319 || Penalty = 0.000026 || Calendar Penalty = 0.000026 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 30 || Loss = 0.057318 || Penalty = 0.000025 || Calendar Penalty = 0.000025 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 31 || Loss = 0.057317 || Penalty = 0.000024 || Calendar Penalty = 0.000024 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 32 || Loss = 0.057316 || Penalty = 0.000023 || Calendar Penalty = 0.000023 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 33 || Loss = 0.057315 || Penalty = 0.000023 || Calendar Penalty = 0.000023 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 34 || Loss = 0.057314 || Penalty = 0.000021 || Calendar Penalty = 0.000021 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 35 || Loss = 0.057315 || Penalty = 0.000021 || Calendar Penalty = 0.000021 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 36 || Loss = 0.057313 || Penalty = 0.000020 || Calendar Penalty = 0.000020 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 37 || Loss = 0.057311 || Penalty = 0.000019 || Calendar Penalty = 0.000019 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 38 || Loss = 0.057312 || Penalty = 0.000019 || Calendar Penalty = 0.000018 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 39 || Loss = 0.057312 || Penalty = 0.000018 || Calendar Penalty = 0.000018 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 40 || Loss = 0.057308 || Penalty = 0.000017 || Calendar Penalty = 0.000017 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 41 || Loss = 0.057309 || Penalty = 0.000016 || Calendar Penalty = 0.000016 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 42 || Loss = 0.057308 || Penalty = 0.000016 || Calendar Penalty = 0.000016 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 43 || Loss = 0.057307 || Penalty = 0.000015 || Calendar Penalty = 0.000015 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 44 || Loss = 0.057308 || Penalty = 0.000015 || Calendar Penalty = 0.000015 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 45 || Loss = 0.057307 || Penalty = 0.000015 || Calendar Penalty = 0.000015 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 46 || Loss = 0.057307 || Penalty = 0.000015 || Calendar Penalty = 0.000015 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 47 || Loss = 0.057306 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 48 || Loss = 0.057306 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 49 || Loss = 0.057307 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 50 || Loss = 0.057306 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 51 || Loss = 0.057307 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 52 || Loss = 0.057307 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 53 || Loss = 0.057306 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 54 || Loss = 0.057306 || Penalty = 0.000014 || Calendar Penalty = 0.000014 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 55 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 56 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 57 || Loss = 0.057304 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 58 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 59 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 60 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 61 || Loss = 0.057304 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 62 || Loss = 0.057307 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 63 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 64 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 65 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 66 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 67 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 68 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 69 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 70 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 71 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 72 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 73 || Loss = 0.057307 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 74 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 75 || Loss = 0.057307 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 76 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 77 || Loss = 0.057307 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 78 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 79 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 80 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 81 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 82 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 83 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 84 || Loss = 0.057307 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 85 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 86 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 87 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 88 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 89 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 90 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 91 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 92 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 93 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 94 || Loss = 0.057304 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 95 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 96 || Loss = 0.057304 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 97 || Loss = 0.057306 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 98 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 99 || Loss = 0.057307 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
# Epoch 100 || Loss = 0.057305 || Penalty = 0.000013 || Calendar Penalty = 0.000013 || Butterfly Penalty = 0.000000 || Large Moneyness Penalty = 0.000000
